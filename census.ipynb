# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Checking the counts of label categories
income = df['Income'].value_counts(normalize=True)
round(income * 100, 2).astype('str') + ' %'
# Out:
#  <=50K    75.92 %
#  >50K     24.08 %
# Name: Income, dtype: object

# %%
#The dataset is unbalanced, as the dependent feature 'income' contains 75.92% values have
#income less than 50k and 24.08% values have income more than 50k.

# %%
#univariate analysis

# %%
# Creating a barplot for 'Income'
income = df['Income'].value_counts()
sns.barplot(income.index, income.values, palette='bright')
plt.title('Distribution of Income')
plt.xlabel('Income')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a distribution plot for 'Age'
age = df['Age'].value_counts()


sns.distplot(df['Age'], bins=20)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a barplot for 'Education'
edu = df['Education'].value_counts()

sns.barplot(edu.values, edu.index, palette='Paired')
plt.title('Distribution of Education')
plt.xlabel('Number of people')
plt.ylabel('Education')
plt.show()

# %%
# Creating a barplot for 'Years of Education'
edu_num = df['Education_num'].value_counts()
sns.barplot(edu_num.index, edu_num.values, palette='colorblind')
plt.title('Distribution of Years of Education')
plt.xlabel('Years of Education')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a pie chart for 'Marital status'
marital = df['Marital_status'].value_counts()
plt.pie(marital.values, labels=marital.index, startangle=10, explode=(
    0, 0.20, 0, 0, 0, 0, 0), shadow=True, autopct='%1.1f%%')
plt.title('Marital distribution')
plt.legend()
plt.legend(prop={'size': 7})
plt.axis('equal')
plt.show()

# %%
# Creating a barplot for 'Sex'
sex = df['Sex'].value_counts()
sns.barplot(sex.index, sex.values)
plt.title('Distribution of Sex')
plt.xlabel('Sex')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a barplot for 'Hours per week'
hours = df['Hours_per_week'].value_counts().head(10)
sns.barplot(hours.index, hours.values, palette='colorblind')
plt.title('Distribution of Hours of work per week')
plt.xlabel('Hours of work')
plt.ylabel('Number of people')
plt.show()

# %%
#lets move o to bivariate analysis

# %%
# Creating a countplot of income across age
plt.figure(figsize=(10, 7))
sns.countplot(df['Age'], hue=df['Income'])
plt.title('Distribution of Income across Age')
plt.xlabel('Age')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a countplot of income across education

plt.figure(figsize=(20, 7))
sns.countplot(df['Education'],
              hue=df['Income'], palette='colorblind')
plt.title('Distribution of Income across Education')
plt.xlabel('Education')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a countplot of income across years of education
plt.figure(figsize=(20, 7))
sns.countplot(df['Education_num'],
              hue=df['Income'])
plt.title('Income across Years of Education')
plt.xlabel('Years of Education')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a countplot of income across Marital Status
plt.figure(figsize=(20, 7))
sns.countplot(df['Marital_status'], hue=df['Income'])
plt.title('Income across Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a countplot of income across race
sns.countplot(df['Race'], hue=df['Income'])
plt.title('Distribution of income across race')
plt.xlabel('Race')
plt.ylabel('Number of people')
plt.show()

# %%
# Creating a countplot of income across sex
sns.countplot(df['Sex'], hue=df['Income'])
plt.title('Distribution of income across sex')
plt.xlabel('Sex')
plt.ylabel('Number of people')
plt.show()

# %%
#Multivariate Analysis

# %%
# Creating a pairplot of dataset
sns.pairplot(df)
plt.show()

# %%
corr = df.corr()

# %%
corr
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %%
sns.heatmap(corr,annot=True, cmap='Greens')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Income'] = le.fit_transform(df['Income'])

# %%
cor=df.corr()

# %%
cor
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
# Income          0.234039 -0.009481       0.335182      0.223333      0.150523
#
#                 Hours_per_week    Income
# Age                   0.068756  0.234039
# Fnlwgt               -0.018770 -0.009481
# Education_num         0.148127  0.335182
# Capital_gain          0.078409  0.223333
# Capital_loss          0.054256  0.150523
# Hours_per_week        1.000000  0.229690
# Income                0.229690  1.000000

# %%
sns.heatmap(cor,annot=True,cmap="Greens")
plt.show()

# %%
#Observations:
#In this dataset, the most number of people are young, white, male, high school graduates
#with 9 to 10 years of education and work 40 hours per week.
#From the correlation heatmap, we can see that the dependent feature 'income' is highly 
#correlated with age, numbers of years of education, capital gain and number of hours per week.

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        le2 = LabelEncoder()
        df[i] = le2.fit_transform(df[i])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
#Feature Selection

# %%
x = df.drop('Income', axis=1)
y = df['Income']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  int32
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  int32
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  int32
#  6   Occupation      32560 non-null  int32
#  7   Relationship    32560 non-null  int32
#  8   Race            32560 non-null  int32
#  9   Sex             32560 non-null  int32
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  int32
# dtypes: int32(8), int64(6)
# memory usage: 2.5 MB

# %%
x = x.drop(['Workclass', 'Education', 'Race', 'Sex','Capital_loss','Native_country'], axis=1)

# %%
x
# Out:
#        Age  Fnlwgt  Education_num  Marital_status  Occupation  Relationship  \
# 0       50   83311             13               2           4             0
# 1       38  215646              9               0           6             1
# 2       53  234721              7               2           6             0
# 3       28  338409             13               2          10             5
# 4       37  284582             14               2           4             5
# ...    ...     ...            ...             ...         ...           ...
# 32555   27  257302             12               2          13             5
# 32556   40  154374              9               2           7             0
# 32557   58  151910              9               6           1             4
# 32558   22  201490              9               4           1             3
# 32559   52  287927              9               2           4             5
#
#        Capital_gain  Hours_per_week
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
for col in x.columns:
    scaler = StandardScaler()
    x[col] = scaler.fit_transform(x[col].values.reshape(-1, 1))

# %%
 #Fixing imbalanced dataset using Oversampling

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 32560, dtype: int32

# %%
round(y.value_counts(normalize=True) * 100, 2).astype('str') + ' %'
# Out:
# 0    75.92 %
# 1    24.08 %
# Name: Income, dtype: object

# %%
from imblearn.over_sampling import RandomOverSampler
ro = RandomOverSampler(random_state=42)

# %%
ro.fit(x, y)
# Out:
# RandomOverSampler(random_state=42)

# %%
x_new, y_new = ro.fit_resample(x, y)

# %%
round(y_new.value_counts(normalize=True) * 100, 2).astype('str') + ' %'
# Out:
# 1    50.0 %
# 0    50.0 %
# Name: Income, dtype: object

# %%
#Creating a train test split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x_new, y_new, test_size=0.3, random_state=42)

# %%
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (34606, 8)
# x_test shape: (14832, 8)
# y_train shape: (34606,)
# y_test shape: (14832,)

# %%
#Data Modelling and evaluation

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
 #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state=42)

# %%
LR.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred_LR = LR.predict(x_test)

# %%
print('Accuracy score:', round(accuracy_score(y_test, y_pred_LR) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_LR) * 100, 2))
# Out:
# Accuracy score: 75.99
# F1 score: 75.98

# %%
#KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn.predict(x_test)

# %%
print('Accuracy score:', round(accuracy_score(y_test, y_pred_knn) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_knn) * 100, 2))
# Out:
# Accuracy score: 82.83
# F1 score: 83.81

# %%
#Support Vector Classifier

# %%
from sklearn.svm import SVC
svc = SVC(random_state=42)

# %%
svc.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred_svc = svc.predict(x_test)

# %%
print('Accuracy score:', round(accuracy_score(y_test, y_pred_svc) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_svc) * 100, 2))
# Out:
# Accuracy score: 82.15
# F1 score: 83.16

# %%
#Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = gnb.predict(x_test)

# %%
print('Accuracy score:', round(accuracy_score(y_test, y_pred_nb) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_nb) * 100, 2))
# Out:
# Accuracy score: 66.27
# F1 score: 52.17

# %%
#Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier(random_state=42)

# %%
DTC.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_DTC = DTC.predict(x_test)

# %%
print('Accuracy score:', round(accuracy_score(y_test, y_pred_DTC) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_DTC) * 100, 2))
# Out:
# Accuracy score: 90.12
# F1 score: 90.63

# %%
#Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
RC = RandomForestClassifier(random_state=42)

# %%
RC.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_RC = RC.predict(x_test)

# %%
print('Accuracy score:', round(accuracy_score(y_test, y_pred_RC) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_RC) * 100, 2))
# Out:
# Accuracy score: 91.74
# F1 score: 92.13

# %%
#Hyperparameter Tuning as the Random forest classifier is havig the heigher accuracy

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start=40, stop=150, num=15)]
max_depth = [int(x) for x in np.linspace(40, 150, num=15)]

# %%
param_dist = {'n_estimators': n_estimators,'max_depth': max_depth,}

# %%
RC_tuned = RandomForestClassifier(random_state=42)

# %%
RC_cv = RandomizedSearchCV(
    estimator=RC_tuned, param_distributions=param_dist, cv=5, random_state=42)

# %%
RC_cv.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'max_depth': [40, 47, 55, 63, 71, 79,
#                                                       87, 95, 102, 110, 118,
#                                                       126, 134, 142, 150],
#                                         'n_estimators': [40, 47, 55, 63, 71, 79,
#                                                          87, 95, 102, 110, 118,
#                                                          126, 134, 142, 150]},
#                    random_state=42)

# %%
RC_cv.best_score_
# Out:
# 0.9063456441022325

# %%
RC_cv.best_params_
# Out:
# {'n_estimators': 110, 'max_depth': 40}

# %%
RC_best = RandomForestClassifier(
    max_depth=102, n_estimators=40, random_state=42)

# %%
RC_best.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=102, n_estimators=40, random_state=42)

# %%
Y_pred_RC_BEST = RC_best.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, Y_pred_RC_BEST)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, Y_pred_RC_BEST))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91      7409
#            1       0.88      0.97      0.92      7423
#
#     accuracy                           0.92     14832
#    macro avg       0.92      0.92      0.92     14832
# weighted avg       0.92      0.92      0.92     14832

# %%
import joblib

# %%
joblib.dump(RC,"RC_MODEL.obj")
# Out:
# ['RC_MODEL.obj']

# %%
RCLOAD=joblib.load("RC_MODEL.obj")
RCLOAD.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 1])
