# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
ds
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df=pd.DataFrame(ds)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
columnss = {'W': 'NO_OF_WINS', 'R': 'RUNS_RECORD', 'AB': 'ATBAT', 
           'H': 'HIT', '2B': 'DOUBLES','3B':'TRIPPLE','HR':'HOME RUNS','BB':'BASE ON BALLS',
           'SO':'STRIKE_OUT','SB':'STOLEN_BASE'
          ,'RA':'RUN_AVG','ER':'EARNED_RUN','ERA':'EARNED_RUN_AVG','CG':'COMPLETE_GAME',
           'SHO':'SHOUTOUT','SV':'SAVE','E':'ERROR'}
rename_df=df.rename(columnss,axis=1,inplace=True)
df
# Out:
#     NO_OF_WINS  RUNS_RECORD  ATBAT   HIT  DOUBLES  TRIPPLE  HOME RUNS  \
# 0           95          724   5575  1497      300       42        139
# 1           83          696   5467  1349      277       44        156
# 2           81          669   5439  1395      303       29        141
# 3           76          622   5533  1381      260       27        136
# 4           74          689   5605  1515      289       49        151
# 5           93          891   5509  1480      308       17        232
# 6           87          764   5567  1397      272       19        212
# 7           81          713   5485  1370      246       20        217
# 8           80          644   5485  1383      278       32        167
# 9           78          748   5640  1495      294       33        161
# 10          88          751   5511  1419      279       32        172
# 11          86          729   5459  1363      278       26        230
# ...

# %%
df.head()
# Out:
#    NO_OF_WINS  RUNS_RECORD  ATBAT   HIT  DOUBLES  TRIPPLE  HOME RUNS  \
# 0          95          724   5575  1497      300       42        139
# 1          83          696   5467  1349      277       44        156
# 2          81          669   5439  1395      303       29        141
# 3          76          622   5533  1381      260       27        136
# 4          74          689   5605  1515      289       49        151
#
#    BASE ON BALLS  STRIKE_OUT  STOLEN_BASE  RUN_AVG  EARNED_RUN  \
# 0            383         973          104      641         601
# 1            439        1264           70      700         653
# 2            533        1157           86      640         584
# 3            404        1231           68      701         643
# 4            455        1259           83      803         746
#
#    EARNED_RUN_AVG  COMPLETE_GAME  SHOUTOUT  SAVE  ERROR
# 0            3.73              2         8    56     88
# 1            4.07              2        12    45     86
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.iloc[:1].shape
# Out:
# (1, 17)

# %%
df.isnull().sum()
# Out:
# NO_OF_WINS        0
# RUNS_RECORD       0
# ATBAT             0
# HIT               0
# DOUBLES           0
# TRIPPLE           0
# HOME RUNS         0
# BASE ON BALLS     0
# STRIKE_OUT        0
# STOLEN_BASE       0
# RUN_AVG           0
# EARNED_RUN        0
# EARNED_RUN_AVG    0
# COMPLETE_GAME     0
# SHOUTOUT          0
# SAVE              0
# ERROR             0
# dtype: int64

# %%
#no null values in the dataset so no need to fill the null values

# %%
df.dtypes
# Out:
# NO_OF_WINS          int64
# RUNS_RECORD         int64
# ATBAT               int64
# HIT                 int64
# DOUBLES             int64
# TRIPPLE             int64
# HOME RUNS           int64
# BASE ON BALLS       int64
# STRIKE_OUT          int64
# STOLEN_BASE         int64
# RUN_AVG             int64
# EARNED_RUN          int64
# EARNED_RUN_AVG    float64
# COMPLETE_GAME       int64
# SHOUTOUT            int64
# SAVE                int64
# ERROR               int64
# dtype: object

# %%
df['EARNED_RUN_AVG'] = df['EARNED_RUN_AVG'].astype(int)
df.head()
# Out:
#    NO_OF_WINS  RUNS_RECORD  ATBAT   HIT  DOUBLES  TRIPPLE  HOME RUNS  \
# 0          95          724   5575  1497      300       42        139
# 1          83          696   5467  1349      277       44        156
# 2          81          669   5439  1395      303       29        141
# 3          76          622   5533  1381      260       27        136
# 4          74          689   5605  1515      289       49        151
#
#    BASE ON BALLS  STRIKE_OUT  STOLEN_BASE  RUN_AVG  EARNED_RUN  \
# 0            383         973          104      641         601
# 1            439        1264           70      700         653
# 2            533        1157           86      640         584
# 3            404        1231           68      701         643
# 4            455        1259           83      803         746
#
#    EARNED_RUN_AVG  COMPLETE_GAME  SHOUTOUT  SAVE  ERROR
# 0               3              2         8    56     88
# 1               4              2        12    45     86
# ...

# %%
df.describe()
# Out:
#        NO_OF_WINS  RUNS_RECORD        ATBAT          HIT     DOUBLES  \
# count   30.000000    30.000000    30.000000    30.000000   30.000000
# mean    80.966667   688.233333  5516.266667  1403.533333  274.733333
# std     10.453455    58.761754    70.467372    57.140923   18.095405
# min     63.000000   573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000   651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000   689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000   718.250000  5570.000000  1451.500000  288.750000
# max    100.000000   891.000000  5649.000000  1515.000000  308.000000
#
#          TRIPPLE   HOME RUNS  BASE ON BALLS  STRIKE_OUT  STOLEN_BASE  \
# count  30.000000   30.000000      30.000000    30.00000    30.000000
# mean   31.300000  163.633333     469.100000  1248.20000    83.500000
# std    10.452355   31.823309      57.053725   103.75947    22.815225
# ...

# %%
df.plot.box
# Out:
# <bound method PlotAccessor.box of <pandas.plotting._core.PlotAccessor object at 0x00000182DE612610>>

# %%
df.plot(kind="box",subplots=True,layout=(2,9),figsize=(10,10))
# Out:
# NO_OF_WINS           AxesSubplot(0.125,0.536818;0.0731132x0.343182)
# RUNS_RECORD       AxesSubplot(0.212736,0.536818;0.0731132x0.343182)
# ATBAT             AxesSubplot(0.300472,0.536818;0.0731132x0.343182)
# HIT               AxesSubplot(0.388208,0.536818;0.0731132x0.343182)
# DOUBLES           AxesSubplot(0.475943,0.536818;0.0731132x0.343182)
# TRIPPLE           AxesSubplot(0.563679,0.536818;0.0731132x0.343182)
# HOME RUNS         AxesSubplot(0.651415,0.536818;0.0731132x0.343182)
# BASE ON BALLS     AxesSubplot(0.739151,0.536818;0.0731132x0.343182)
# STRIKE_OUT        AxesSubplot(0.826887,0.536818;0.0731132x0.343182)
# STOLEN_BASE             AxesSubplot(0.125,0.125;0.0731132x0.343182)
# RUN_AVG              AxesSubplot(0.212736,0.125;0.0731132x0.343182)
# EARNED_RUN           AxesSubplot(0.300472,0.125;0.0731132x0.343182)
# EARNED_RUN_AVG       AxesSubplot(0.388208,0.125;0.0731132x0.343182)
# COMPLETE_GAME        AxesSubplot(0.475943,0.125;0.0731132x0.343182)
# ...

# %%
#outliers are present in the column ERROR as there is much differnce between the 75th percentile and the maximum value

# %%
df.corr()
# Out:
#                 NO_OF_WINS  RUNS_RECORD     ATBAT       HIT   DOUBLES  \
# NO_OF_WINS        1.000000     0.430751 -0.087947  0.037612  0.427797
# RUNS_RECORD       0.430751     1.000000  0.319464  0.482856  0.560084
# ATBAT            -0.087947     0.319464  1.000000  0.739122  0.453370
# HIT               0.037612     0.482856  0.739122  1.000000  0.566847
# DOUBLES           0.427797     0.560084  0.453370  0.566847  1.000000
# TRIPPLE          -0.251118    -0.070072  0.435422  0.478694  0.220490
# HOME RUNS         0.307407     0.671283 -0.066983 -0.090855  0.056292
# BASE ON BALLS     0.484342     0.402452 -0.136414 -0.118281  0.302700
# STRIKE_OUT        0.111850    -0.054726 -0.106022 -0.398830 -0.150752
# STOLEN_BASE      -0.157234     0.081367  0.372618  0.413444  0.195027
# RUN_AVG          -0.812952    -0.041623  0.316010  0.224324 -0.218160
# EARNED_RUN       -0.809435    -0.041245  0.309686  0.252489 -0.235531
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#RUN_avg,EARNED_RUN,EARNED_RUN_AVG are contributing negatively over the no of wins

# %%
df.head()
# Out:
#    NO_OF_WINS  RUNS_RECORD  ATBAT   HIT  DOUBLES  TRIPPLE  HOME RUNS  \
# 0          95          724   5575  1497      300       42        139
# 1          83          696   5467  1349      277       44        156
# 2          81          669   5439  1395      303       29        141
# 3          76          622   5533  1381      260       27        136
# 4          74          689   5605  1515      289       49        151
#
#    BASE ON BALLS  STRIKE_OUT  STOLEN_BASE  RUN_AVG  EARNED_RUN  \
# 0            383         973          104      641         601
# 1            439        1264           70      700         653
# 2            533        1157           86      640         584
# 3            404        1231           68      701         643
# 4            455        1259           83      803         746
#
#    EARNED_RUN_AVG  COMPLETE_GAME  SHOUTOUT  SAVE  ERROR
# 0               3              2         8    56     88
# 1               4              2        12    45     86
# ...

# %%
sns.regplot(x="RUNS_RECORD",y="NO_OF_WINS",data=df)
# Out:
# <AxesSubplot:xlabel='RUNS_RECORD', ylabel='NO_OF_WINS'>

# %%
#runs record is strongly correlated with the no of wins

# %%
sns.regplot(x="ATBAT",y="NO_OF_WINS",data=df)
# Out:
# <AxesSubplot:xlabel='ATBAT', ylabel='NO_OF_WINS'>

# %%
sns.regplot(x="ERROR",y="NO_OF_WINS",data=df)
# Out:
# <AxesSubplot:xlabel='ERROR', ylabel='NO_OF_WINS'>

# %%
sns.regplot(x="STRIKE_OUT",y="NO_OF_WINS",data=df)
# Out:
# <AxesSubplot:xlabel='STRIKE_OUT', ylabel='NO_OF_WINS'>

# %%
#RUN_avg,EARNED_RUN,EARNED_RUN_AVG are contributing negatively over the no of wins
#we will drop the columns

# %%
df.head()
# Out:
#    NO_OF_WINS  RUNS_RECORD  ATBAT   HIT  DOUBLES  TRIPPLE  HOME RUNS  \
# 0          95          724   5575  1497      300       42        139
# 1          83          696   5467  1349      277       44        156
# 2          81          669   5439  1395      303       29        141
# 3          76          622   5533  1381      260       27        136
# 4          74          689   5605  1515      289       49        151
#
#    BASE ON BALLS  STRIKE_OUT  STOLEN_BASE  RUN_AVG  EARNED_RUN  \
# 0            383         973          104      641         601
# 1            439        1264           70      700         653
# 2            533        1157           86      640         584
# 3            404        1231           68      701         643
# 4            455        1259           83      803         746
#
#    EARNED_RUN_AVG  COMPLETE_GAME  SHOUTOUT  SAVE  ERROR
# 0               3              2         8    56     88
# 1               4              2        12    45     86
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x=df.drop(columns=["NO_OF_WINS"])
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.86266219, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.75482941, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.86266219,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217, -0.86266219,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
# ...

# %%
import scipy.stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif["VIF Factors"]=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)

# %%
vif_cal()
# Out:
#      VIF Factors        features
# 0    1483.054070     RUNS_RECORD
# 1    3917.344542           ATBAT
# 2    4217.563704             HIT
# 3     967.087144         DOUBLES
# 4      34.556022         TRIPPLE
# 5     246.547664       HOME RUNS
# 6     286.487560   BASE ON BALLS
# 7     403.010200      STRIKE_OUT
# 8      28.131101     STOLEN_BASE
# 9   16151.257521         RUN_AVG
# 10  14302.868542      EARNED_RUN
# 11    261.874156  EARNED_RUN_AVG
# 12      7.567076   COMPLETE_GAME
# 13     30.475728        SHOUTOUT
# 14    116.724291            SAVE
# 15     86.211586           ERROR

# %%
#run avg and earned_run are having same vales hence one of them can be dropped as there is the multicolinearity to reduce the cost of the model.

# %%
df=df.drop(columns=["RUN_AVG"])

# %%
df.shape
# Out:
# (30, 16)

# %%
x=x_scaled
x
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.86266219, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.75482941, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.86266219,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217, -0.86266219,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
# ...

# %%
#splitting the data
x=pd.DataFrame(x)
x
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
y=df.iloc[:,0]
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: NO_OF_WINS, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=45)

# %%
LR=LinearRegression()

# %%
LR.fit(xtrain,ytrain)
LR.coef_
# Out:
# array([  9.74981049,   1.28560414,  -1.79195239,  -2.4489839 ,
#          0.49635543,  -2.91246691,  -0.94193831,   0.48447301,
#         -0.0524694 ,  10.73765012, -12.37060927,  -3.34029322,
#          1.38384672,   1.31848916,   5.16342599,  -1.97000295])

# %%
LR.intercept_
# Out:
# 80.90431779313501

# %%
LR.score(xtrain,ytrain)
# Out:
# 0.9537622811161477

# %%
PRED=LR.predict(xtest)
PRED
# Out:
# array([92.36689636, 83.28524208, 87.89871449, 99.91696953, 73.8380804 ,
#        81.21168812, 67.61263449, 81.99039136, 83.00891696])

# %%
print("predicted values",PRED)
# Out:
# predicted values [92.36689636 83.28524208 87.89871449 99.91696953 73.8380804  81.21168812
#  67.61263449 81.99039136 83.00891696]

# %%
LR.score(xtest,ytest)
# Out:
# 0.7911650929943388

# %%
print("MAE::",mean_absolute_error(ytest,PRED))
print("MSE::",mean_squared_error(ytest,PRED))
print("RMSE::",np.sqrt(mean_squared_error(ytest,PRED)))
# Out:
# MAE:: 3.6310053773511033
# MSE:: 17.310093402913697
# RMSE:: 4.160540037412655

# %%
print("R2 score::",r2_score(ytest,PRED))
# Out:
# R2 score:: 0.7911650929943388

# %% [markdown]
# regularisation

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet
from sklearn.metrics import r2_score
RD=Ridge(alpha=0.001,random_state=46)
RD.fit(xtrain,ytrain)
RD.score(xtrain,ytrain)
# Out:
# 0.9537606028070114

# %%
RD.coef_
# Out:
# array([  9.74357632,   1.28796785,  -1.80280102,  -2.44319006,
#          0.49946541,  -2.92026815,  -0.93268261,   0.49037732,
#         -0.05745983,  10.56869178, -12.20512255,  -3.34019231,
#          1.38331847,   1.31059884,   5.15360214,  -1.96579173])

# %%
predict=RD.predict(xtest)

# %%
r2_score(ytest,predict)
# Out:
# 0.7920286367280449

# %%
lss=Lasso(alpha=0.001,random_state=47)
lss.fit(xtrain,ytrain)
lss.score(xtrain,ytrain)
# Out:
# G:\PYTHON\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:645: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.788e-01, tolerance: 2.329e-01
#   model = cd_fast.enet_coordinate_descent(
# 0.953755362076406

# %%
predictt=lss.predict(xtest)

# %%
r2_score(ytest,predictt)
# Out:
# 0.7933619911825753

# %% [markdown]
# approching more regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DTC=DecisionTreeRegressor(criterion="mse")
DTC.fit(xtrain,ytrain)
print("DTC",DTC.score(xtrain,ytrain))



DTCpredict=DTC.predict(xtest)
print("DTC r2_score",r2_score(ytest,DTCpredict))
print("MSE of DTC::",mean_squared_error(ytest,PRED))
print("RMSE of DTC::",np.sqrt(mean_squared_error(ytest,PRED)))
# Out:
# DTC 1.0
# DTC r2_score -0.6943699731903485
# MSE of DTC:: 17.310093402913697
# RMSE of DTC:: 4.160540037412655
# G:\PYTHON\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
kn=KNeighborsRegressor()
kn.fit(xtrain,ytrain)
print("knn",kn.score(xtrain,ytrain))



knpredict=kn.predict(xtest)
print("kn r2_score",r2_score(ytest,knpredict))
print("MSE of kn::",mean_squared_error(ytest,PRED))
print("RMSE of kn::",np.sqrt(mean_squared_error(ytest,PRED)))
# Out:
# knn 0.7359823363454225
# kn r2_score 0.40514745308310995
# MSE of kn:: 17.310093402913697
# RMSE of kn:: 4.160540037412655

# %%
from sklearn.svm  import SVR

# %%
svr=SVR()
svr.fit(xtrain,ytrain)
print("svr",svr.score(xtrain,ytrain))



svrpredict=svr.predict(xtest)
print("svr r2_score",r2_score(ytest,svrpredict))
print("MSE of svr::",mean_squared_error(ytest,PRED))
print("RMSE of svr::",np.sqrt(mean_squared_error(ytest,PRED)))
# Out:
# svr 0.2599780041814148
# svr r2_score -0.0180624703310992
# MSE of svr:: 17.310093402913697
# RMSE of svr:: 4.160540037412655

# %%
from sklearn.linear_model  import SGDRegressor

sgd=SGDRegressor()
sgd.fit(xtrain,ytrain)
print("DTC score",sgd.score(xtrain,ytrain))
sgdpredict=sgd.predict(xtest)
print("DTCr2_score",r2_score(ytest,sgdpredict))
print("MSE of DTC::",mean_squared_error(ytest,PRED))
print("RMSE of DTC::",np.sqrt(mean_squared_error(ytest,PRED)))
# Out:
# DTC score 0.9362689682199243
# DTCr2_score 0.7497499014192917
# MSE of DTC:: 17.310093402913697
# RMSE of DTC:: 4.160540037412655

# %%
from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor(n_estimators=50,random_state=43)
rf.fit(xtrain,ytrain)
predrf=rf.predict(xtest)



print(predrf)


print("rf score",rf.score(xtrain,ytrain))

print("rf r2_score",r2_score(ytest,predrf))
# Out:
# [93.24 76.8  87.84 84.78 74.3  71.9  69.64 81.32 74.78]
# rf score 0.9226662141718117
# rf r2_score 0.5575978552278822

# %%
from sklearn.ensemble import AdaBoostRegressor
ADA=AdaBoostRegressor(n_estimators=50,random_state=43)
ADA.fit(xtrain,ytrain)
predADA=ADA.predict(xtest)



print(predADA)


print("ADA score",ADA.score(xtrain,ytrain))

print("ADA r2_score",r2_score(ytest,predADA))
# Out:
# [96.4  74.   87.   82.   76.   72.   72.5  80.75 75.2 ]
# ADA score 0.9886563868277182
# ADA r2_score 0.47223525469168914

# %%
from sklearn.ensemble import GradientBoostingRegressor
GB=GradientBoostingRegressor()
GB.fit(xtrain,ytrain)
predGB=GB.predict(xtest)



print(predGB)


print("GB score",GB.score(xtrain,ytrain))

print("GB r2_score",r2_score(ytest,predGB))
# Out:
# [97.81933801 74.6080884  88.87436552 84.06673726 68.97095475 72.12317778
#  69.46384033 80.86953047 69.5401684 ]
# GB score 0.999999736048756
# GB r2_score 0.2818176269334213

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import KFold
kfold=KFold(5)
score=cross_val_score(DTC,x,y,cv=kfold)
print(score)
print(score.mean())
print(score.std())
# Out:
# [-1.4991119  -9.99236641 -0.60624524 -0.34505495  0.47633136]
# -2.393289427352681
# 3.8514682748870204
# G:\PYTHON\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# G:\PYTHON\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# G:\PYTHON\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# G:\PYTHON\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# ...

# %%
from sklearn.model_selection import KFold
kfold=KFold(5)
score=cross_val_score(kn,x,y,cv=kfold)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.23758437 -3.86503817  0.34694593  0.36303925  0.58745562]
# -0.4660026010716388
# 1.7033171946413177

# %%
from sklearn.model_selection import KFold
kfold=KFold(5)
score=cross_val_score(svr,x,y,cv=kfold)
print(score)
print(score.mean())
print(score.std())
# Out:
# [-0.09897934 -0.91894316 -0.27243513 -0.60412979 -0.01526701]
# -0.38195088763170193
# 0.33593089495748507

# %%
from sklearn.model_selection import KFold
kfold=KFold(5)
score=cross_val_score(RD,x,y,cv=kfold)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.6845218  -4.12443357  0.42633054  0.73623827  0.69629851]
# -0.3162088903040682
# 1.9072607656157716

# %%
from sklearn.model_selection import KFold
kfold=KFold(5)
score=cross_val_score(GB,x,y,cv=kfold)
print(score)
print(score.mean())
print(score.std())
# Out:
# [-0.12347971 -6.57605366  0.26091652  0.33320164  0.5702057 ]
# -1.1070419044389683
# 2.743583621424063

# %%
from sklearn.model_selection import KFold
kfold=KFold(5)
score=cross_val_score(lss,x,y,cv=kfold)
print(score)
print(score.mean())
print(score.std())
# Out:
# G:\PYTHON\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:645: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.070e+01, tolerance: 2.739e-01
#   model = cd_fast.enet_coordinate_descent(
# G:\PYTHON\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:645: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e+01, tolerance: 3.040e-01
#   model = cd_fast.enet_coordinate_descent(
# G:\PYTHON\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:645: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.426e+00, tolerance: 1.990e-01
# ...
